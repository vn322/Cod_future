# %% [markdown]
# <a href="https://colab.research.google.com/github/vn322/Cod_future/blob/main/%D0%A0%D0%B5%D1%88%D0%B5%D0%BD%D0%B8%D0%B5_%D0%9E%D1%81%D0%BD%D0%BE%D0%B2%D1%8B_%D0%BC%D0%B0%D1%82%D0%B5%D0%BC%D0%B0%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%BE%D0%B3%D0%BE_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7%D0%B0_%D0%B8_%D0%BB%D0%B8%D0%BD%D0%B5%D0%B9%D0%BD%D0%BE%D0%B9_%D0%B0%D0%BB%D0%B3%D0%B5%D0%B1%D1%80%D1%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Математика в машинном обучении

# %% [markdown]
# Машинное обучение требует от разработчика, инженера знаний следующих разделов математической науки:
#
# - аналитическая геометрия и линейная алгебра;
#
# - математический анализ;
#
# - теория вероятностей, комбинаторика и статистика.
#
# Специалисты придают разный вес этим разделам, как например на [рисунке](https://tomcircle.wordpress.com/tag/gradient-descent/) и здесь мы остановимся подробнее на первых двух.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Аналитическая геометрия и линейная алгебра помогают нам использовать операции с векторами и матрицами, как простые (сложение, умножение на число или умножение самих матриц), так и продвинутые такие как сингулярное разложение матриц (Singular Value Decomposition, SVD), метод главных компонент (Principal Component Analysis, PCA) и метод опорных векторов (Support Vector Machines, SVM). Действительно все объекты в машинном обучении можно представить в виде векторов и матриц. Строка и даже один символ из набора данных – это вектор. Сам набор данных – это система векторов или матрица. Изображение, которое будет распознавать сверточная нейронная сеть – также матрица. Градиент функции потерь – это вектор, и так далее.
# Сам же градиент и метод градиентного спуска (Steepest Descent или Gradient Method) будет относиться к математическому анализу как и функции, в том числе и функции многих переменных, их производные и дифференциалы, а так же основанные на них сложные инструменты, такие как метод обратного распространения ошибки (Вackpropagation).

# %% [markdown]
# # Векторы

# %% [markdown]
# Вектор - это кортеж из одного или нескольких значений-скаляров. Векторы строятся из компонентов, которые являются обычными числами. Вы можете думать о векторе как о списке чисел, а о векторной алгебре как об операциях, выполняемых над числами в списке.
#
# При этом так же верно представление о векторе как о направленном отрезке с определёнными координатами. Поэтому вектор может быть записан своими координатами, например запись вектора в известных вам прямоугольных (декартовых координатах) может быть такой:  $\vec{a} = 3i + 2j$ это значит, что вектор имеет координаты $x = 3$ и $y = 2$ или $\overline{(3;2)}$
#
# Буквы обозначают $i, j$ обозначают базисные векторы, они единичны по размеру и совпадают по направлению с осями координат. Так трёхмерный базис представляется базисными векторами:
#
# $$\overline{i}(1;0;0)$$
#
# $$\overline{j}(0;1;0)$$
#
# $$\overline{k}(0;0;1)$$

# %% [markdown]
# Если нам даны две точки $${A}(x1;y1;z1)$$ $${B}(x2;y2;z2)$$  то вектор будет иметь следующие координаты $$\overline{AB}(x2-x1;y2-y1;z2-z1)$$

# %% [markdown]
# Длина такого вектора определяется при помощи теоремы Пифагора $$|AB|=\sqrt{(x1-x2)^2 + (y1-y2)^2+(z1-z2)^2}$$

# %% [markdown]
# Для того, чтобы сложить векторы, нужно сложить их соответствующие координаты:
# $$\overline{a}(1;2;3) + \overline{b}(4;5;6) = \overline{(5;7;9)}$$

# %% [markdown]
# Для того чтобы вектор  умножить на число , нужно каждую координату данного вектора умножить на число $$\overline{(1;2;3) }*2 = \overline{(2;4;6)}$$

# %% [markdown]
#  Скалярным произведением двух векторов называется число, равное произведению длин этих векторов на косинус угла между ними:
# Формула скалярного произведения $$\overline{a}\cdot\overline{b} = |\overline{a}|\cdot|\overline{b}|\cdot cos\angle(\overline{a};\overline{b})$$

# %% [markdown]
# ## Задания:

# %% [markdown]
# 1. Даны две точки $A(-1;4;1)$ и $B(-3;6;5)$ определить векторы $\overrightarrow{AB}$ и $\overleftarrow{AB}$ и длину $|AB|$

# %% [markdown]
# **Решение**
#
# $\overrightarrow{AB}(-4;2;4)$
#
# $\overleftarrow{AB}(4;-2;4)$
#
# $|AB|=\sqrt{16 + 4 + 16} = 6$

# %% [markdown]
# 2. Даны два вектора $\vec{a}(-1;3)$ и $\vec{b}(5;4)$ вычислить выражение $3*\vec{a} + 2*\vec{b}$

# %% [markdown]
# **Решение**
#
# $3*\vec{a} - 2*\vec{b} = (-3-10;9-8) = (-13;1)$

# %% [markdown]
# 3. Найти скалярное произведение $\overline{a}\cdot\overline{b}$ где:
#
# $$\overline{a}(8;-6)$$
# $$\overline{b}(12;5)$$
#
# $$\angle(\overline{a};\overline{b}) = \frac{\pi}{3}$$

# %% [markdown]
# **Решение**
#
# $\overline{a}\cdot\overline{b} = 10 * 13 * 0.5 = 65 $

# %% [markdown]
# # Матрицы

# %% [markdown]
# Матрица - это массив элементов, представленный в виде прямоугольной таблицы, для которой определены правила математических действий. В качестве элементов могут использоваться числа, символы и функции. Матрицы эффективно применяются при решении систем линейных уравнений. Например систему уравнений:
#
# $\begin{cases}a_{11}x_{1}+a_{12}x_{2}=b_{1}\\a_{21}x_{2}+a_{22}x_{2}=b_{2}\\a_{31}x_{3}+a_{32}x_{3}=b_{3}\end{cases}$
#
# можно представить в виде: $Ax = b$, где:
#
# $A = \begin{pmatrix}
#   a_{11}& a_{12}\\
#   a_{21}& a_{22}\\
#   a_{31}& a_{32}
# \end{pmatrix}$ $x = \begin{pmatrix}
#   x_{1}\\
#   x_{2}\\
#   x_{3}
# \end{pmatrix}$ $b = \begin{pmatrix}
#   b_{1}\\
#   b_{2}\\
#   b_{3}
# \end{pmatrix}$

# %% [markdown]
# **Умножение** матрицы на число производится умножением каждого элемента матрицы на это число.
#
# $-2*\begin{pmatrix}
#   2& 3\\
#  4& 5\\
#   6& 7
# \end{pmatrix}$  $ = \begin{pmatrix}
#  -4& -6\\
#  -8& -10\\
#   -12& -14
# \end{pmatrix}$ $ = -\begin{pmatrix}
#  4& 6\\
#  8& 10\\
#   12& 14
# \end{pmatrix}$

# %% [markdown]
# **Транспонирование** матрицы осуществляется таким образом, что строки записываются в столбцы.
#
# $A = \begin{pmatrix}
#   2& 3\\
#  4& 5\\
#   6& 7
# \end{pmatrix}$ $A^{T} = \begin{pmatrix}
#   2& 4&6\\
#  3& 5& 7
# \end{pmatrix}$

# %% [markdown]
# **Сумма** (разность) матриц возможна только если они одного размера.
#
# $\begin{pmatrix}
#   2& 3\\
#  4& 5
# \end{pmatrix}$ $ + \begin{pmatrix}
#   2& 6\\
#  4& 1
# \end{pmatrix}$ $=\begin{pmatrix}
#   4& 9\\
#  8& 6
# \end{pmatrix}$

# %% [markdown]
# **Умножение матриц А*В** возможно если количество столбцов матрицы А равнялось количеству строк матрицы В. Например мы можем умножить матрицу строку на матрицу столбец, а наоборот это невозможно:
#
# $A = \begin{pmatrix}
#   2& 4&6
# \end{pmatrix}$
#
# $B = \begin{pmatrix}
#   1\\
#  2\\
#   3
# \end{pmatrix}$
#
# $AB = 2*1+4*2+6*3 = 28$
#
# $BA =$ **невозжмоно**

# %% [markdown]
# ## Задание

# %% [markdown]
#  Вычислить выражение $AB-4C^{Т}$
#
# $A = \begin{pmatrix}
#   2& 1\\
#  3& 3\\
#   -1& 2
# \end{pmatrix};$  $B = \begin{pmatrix}
#   -5& 1\\
#  3& -2
# \end{pmatrix};$ $C^{T} = \begin{pmatrix}
#   -5& 1&7\\
#  1& 3& 2
# \end{pmatrix}$

# %% [markdown]
# **Решение**
#
# $AB-4C^{Т} = \begin{pmatrix}
#   13& -4\\
#  -10& -15\\
#   -17& -13
# \end{pmatrix}$
