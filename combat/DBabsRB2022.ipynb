# %% [markdown]
# <a href="https://colab.research.google.com/github/vn322/Cod_future/blob/main/combat/DBabsRB2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
#import seaborn as sns
#import matplotlib
#import matplotlib.pyplot as plt

# %% [markdown]
# # download

# %%
df_act= pd.read_excel('https://github.com/vn322/Sport-University/raw/refs/heads/main/combat/%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7%20%D0%9A%D0%BE%D0%BA%D0%B8%D0%BD,%20%D0%A1%D0%B2%D0%B5%D1%80%D1%87%D0%BA%D0%BE%D0%B2,%20%D0%A5%D0%B0%D1%87%D0%B0%D1%82%D1%80%D1%8F%D0%BD.xlsx', sheet_name= 0)
df_act.head(3)
# Out:
#     fighter1   fighter2          stage  start_ep    end_ep  attacker  \
# 0  ilkvl0198  karma0692  четвертьфинал  04:47:00  04:48:00         1
# 1  ilkvl0198  karma0692  четвертьфинал  04:31:00  04:30:00         2
# 2  ilkvl0198  karma0692  четвертьфинал  04:28:00  04:26:00         2
#
#   actions_1            actions_2 results_1 results_2
# 0     алнбк                алрпг         1         0
# 1        бл                апрпк         0         0
# 2     апрбг  апрпг, апрпг, алрпг         1     1,0,0

# %%
df_par= pd.read_excel('https://github.com/vn322/Sport-University/raw/refs/heads/main/combat/%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7%20%D0%9A%D0%BE%D0%BA%D0%B8%D0%BD,%20%D0%A1%D0%B2%D0%B5%D1%80%D1%87%D0%BA%D0%BE%D0%B2,%20%D0%A5%D0%B0%D1%87%D0%B0%D1%82%D1%80%D1%8F%D0%BD.xlsx', sheet_name= 1)
df_par.head(3)
# Out:
#           id               name      nation  place  weight_over_73  birthdate
# 0  gusil0194     GUSEYNOV IIgar      Russia      1               0 1994-01-21
# 1  makda0401   MAKAGONOV Daniel      Russia      2               0 2001-04-03
# 2  khias0501  KHIKMATOV Asadbek  Uzbekistan      3               0 2001-05-16

# %%
df_spr= pd.read_excel('https://github.com/vn322/Sport-University/raw/refs/heads/main/combat/%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7%20%D0%9A%D0%BE%D0%BA%D0%B8%D0%BD,%20%D0%A1%D0%B2%D0%B5%D1%80%D1%87%D0%BA%D0%BE%D0%B2,%20%D0%A5%D0%B0%D1%87%D0%B0%D1%82%D1%80%D1%8F%D0%BD.xlsx', sheet_name= 2)
df_spr.head(3)
# Out:
#   action abbreviation                                      description
# 0  атака        алрпг   атака левой рукой прямой удар в область головы
# 1  атака        апрпг  атака правой рукой прямой удар в область головы
# 2  атака        алнбк        атака левой ногой боковой удар в туловище

# %% [markdown]
# # simple DB

# %%
import sqlite3

con = sqlite3.connect("absrb2022.db")
cur = con.cursor()

# %%
df_act.to_sql("actions", con=con, if_exists="append", index=False)
# Out:
# 375

# %%
df_spr.to_sql("guide", con=con, if_exists="append", index=False)
# Out:
# 30

# %%
df_par.to_sql("participants", con=con, if_exists="append", index=False)
# Out:
# 40

# %%
pd.read_sql('''
    SELECT *
    FROM actions
''', con)
# Out:
#       fighter1   fighter2          stage         start_ep           end_ep  \
# 0    ilkvl0198  karma0692  четвертьфинал  04:47:00.000000  04:48:00.000000
# 1    ilkvl0198  karma0692  четвертьфинал  04:31:00.000000  04:30:00.000000
# 2    ilkvl0198  karma0692  четвертьфинал  04:28:00.000000  04:26:00.000000
# 3    ilkvl0198  karma0692  четвертьфинал  04:26:00.000000  04:25:00.000000
# 4    ilkvl0198  karma0692  четвертьфинал  04:12:00.000000  04:10:00.000000
# ..         ...        ...            ...              ...              ...
# 370  nizul0198  fedni0301          финал  02:37:00.000000  02:33:00.000000
# 371  nizul0198  fedni0301          финал  02:32:00.000000  02:28:00.000000
# 372  nizul0198  fedni0301          финал  02:24:00.000000  02:21:00.000000
# 373  nizul0198  fedni0301          финал  02:20:00.000000  02:17:00.000000
# 374  nizul0198  fedni0301          финал  02:16:00.000000  02:14:00.000000
#
#      attacker          actions_1            actions_2 results_1 results_2
# 0           1              алнбк                алрпг         1         0
# 1           2                 бл                апрпк         0         0
# 2           2              апрбг  апрпг, апрпг, алрпг         1     1,0,0
# 3           1                ппб                  зот         А         0
# 4           1       апнпк, апрпг            бл, алнлк         0         0
# ..        ...                ...                  ...       ...       ...
# 370         1              апрпг                апрпг         1         0
# 371         1  апрпг,алрпг,алнпк                апнбк     1,0,1         1
# 372         1  апрпг,алнпк,алрбг                  зон     1,1,0         0
# 373         1  алрпг,алнбк,апнпк             бл,бл,бл     0,0,0     0,0,0
# 374         1              апрпг                    -         1         0
#
# [375 rows x 10 columns]

# %%
pd.read_sql('''
    SELECT *
    FROM participants
''', con)
# Out:
#            id                           name                  nation  place  \
# 0   gusil0194                 GUSEYNOV IIgar                  Russia      1
# 1   makda0401               MAKAGONOV Daniel                  Russia      2
# 2   khias0501              KHIKMATOV Asadbek              Uzbekistan      3
# 3   dravl0587                 DRACH Vladimir                 Belarus      3
# 4   ilkvl0198             ILKOVICH Vladislav                 Belarus      5
# 5   musam0499                    MUSAEV Aman         Kyrgyz Republic      5
# 6   husah0390              HUSSEIN Ahmad Ali                 Lebanon      7
# 7   ergim0795               ERGASHEV Imomali              Uzbekistan      7
# 8   elahm0900               EL-AHMAD Miqdaam                   Syria      9
# 9   racul0297            RAKHATBEKOV Ulukbek         Kyrgyz Republic      9
# 10  hasze1297                   HASIEV Zelim  Republic South Ossetia     11
# 11  makzo1004            MAKHSUDOV ZOKHIDDIN              Tajikistan     11
# 12  bekan0395            BEKEMBETOV Anuarbek              Kazakhstan     13
# 13  karma0692              KARGINOV Maharbeg  Republic South Ossetia     13
# 14  hotna0102               HOTAK Nawidullah             Afghanistan     15
# 15  bastu1202                 BASHIROV Tural              Azerbaijan     15
# 16  valel0102                   VALIEV ELVIN                 Georgia     15
# 17  bilmu0995                 BILAL Muhammad                Pakistan     15
# 18  alcyo0493                 ALCHBLI Younes                   Egypt     19
# 19  himpr0903                 HIMESH Prakash                   India     19
# 20  nizul0198           NIZOMIDDINOV Ulugbek              Uzbekistan      1
# 21  fedni0301            FEDYANOVICH Nikolai                  Russia      2
# 22  maggi0295        MAGOMEDOV Gitinomagomed                  Russia      3
# 23  kamil1296                  KAMILOV Ilyos              Uzbekistan      3
# 24  sabza0698                SABANOV Zaurbeg  Republic South Ossetia      5
# 25  kozro0598                  KOZAEV Robert  Republic South Ossetia      5
# 26  barmo0898          BARAKI Mohammad Hafiz             Afghanistan      7
# 27  paiuu0497         PAIZILDA Uulu Damirbek         Kyrgyz Republic      7
# 28  ataba1295              ATAMYRADOV Bayram            Turkmenistan      9
# 29  orosa0690             OROZAKUNOV Salamat         Kyrgyz Republic      9
# 30  gauro0181                    GAUB Robert                 Germany     11
# 31  nasbe0689                  NASIHATOV Bek              Kazakhstan     11
# 32  lapiv0996                  LAPICKIY Ivan                 Belarus     13
# 33  abeal0389    ABED Alnabi Feda Azeez Naim                  Jordan     13
# 34  manab0499  MANGO Abdel Rahman Emad Nazmi                  Jordan     15
# 35  dubal0385                 DUBOVIK Alexey                 Belarus     15
# 36  qasel1193                  QASIMOV Elcan              Azerbaijan     15
# 37  alish0185            ALI Shahzada Kashif                Pakistan     15
# 38  razre1197                    RAZAVI Reza                    Iran     19
# 39  phoch0288    PHONGWANKITTIKUN Chaiyapong                Thailand     19
#
#     weight_over_73            birthdate
# 0                0  1994-01-21 00:00:00
# 1                0  2001-04-03 00:00:00
# 2                0  2001-05-16 00:00:00
# 3                0  1987-05-26 00:00:00
# 4                0  1998-01-23 00:00:00
# 5                0  1999-04-01 00:00:00
# 6                0  1990-03-23 00:00:00
# 7                0  1995-07-07 00:00:00
# 8                0  2000-09-23 00:00:00
# 9                0  1997-02-26 00:00:00
# 10               0  1997-12-06 00:00:00
# 11               0  2004-10-15 00:00:00
# 12               0  1995-03-08 00:00:00
# 13               0  1992-06-19 00:00:00
# 14               0  2002-01-20 00:00:00
# 15               0  2002-12-13 00:00:00
# 16               0  2002-01-05 00:00:00
# 17               0  1995-09-07 00:00:00
# 18               0  1993-04-28 00:00:00
# 19               0  2003-09-23 00:00:00
# 20               1  1998-01-19 00:00:00
# 21               1  2001-03-25 00:00:00
# 22               1  1995-02-20 00:00:00
# 23               1  1996-12-12 00:00:00
# 24               1  1998-06-14 00:00:00
# 25               1  1998-05-10 00:00:00
# 26               1  1998-08-12 00:00:00
# 27               1  1997-04-22 00:00:00
# 28               1  1995-12-24 00:00:00
# 29               1  1990-06-12 00:00:00
# 30               1  1981-01-01 00:00:00
# 31               1  1989-06-29 00:00:00
# 32               1  1996-09-12 00:00:00
# 33               1  1989-03-27 00:00:00
# 34               1  1999-04-21 00:00:00
# 35               1  1985-03-25 00:00:00
# 36               1  1993-11-18 00:00:00
# 37               1  1985-01-08 00:00:00
# 38               1  1997-11-05 00:00:00
# 39               1  1988-02-07 00:00:00

# %% [markdown]
# #t62b

# %%
with con:
    cur.execute("""
        CREATE TABLE participants1 (
            id INT NOT NULL PRIMARY KEY,
            name TEXT,
            nation TEXT,
            place INTEGER,
            weight_over_73 INTEGER,
            birthdate DATE
        );
    """)

# %%
with con:
    cur.execute ("""
        CREATE TABLE actions1 (
            fighter1 TEXT,
            fighter2 TEXT,
            stage INT,
            start_ep TIME,
            end_ep TIME,
            attacker INT,
            actions_1 TEXT,
            actions_2 TEXT,
            results_1 TEXT,
            results_2 TEXT,

            PRIMARY KEY(fighter1, fighter2),
            FOREIGN KEY(fighter1) REFERENCES participants(id),
            FOREIGN KEY(fighter2) REFERENCES participants(id)
        );
    """)

# %%
df_act.to_sql("actions1", con=con, if_exists="append", index=False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-12-4a2caede10e5> in <cell line: 0>()
# ----> 1 df_act.to_sql("actions1", con=con, if_exists="append", index=False)
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3085         from pandas.io import sql
#    3086
# -> 3087         return sql.to_sql(
#    3088             self,
#    3089             name,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     840
#     841     with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842         return pandas_sql.to_sql(
#     843             frame,
#     844             name,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2849         )
#    2850         table.create()
# -> 2851         return table.insert(chunksize, method)
#    2852
#    2853     def has_table(self, name: str, schema: str | None = None) -> bool:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in insert(self, chunksize, method)
#    1117
#    1118                 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1119                 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1120                 # GH 46891
#    1121                 if num_inserted is not None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#    2545     def _execute_insert(self, conn, keys, data_iter) -> int:
#    2546         data_list = list(data_iter)
# -> 2547         conn.executemany(self.insert_statement(num_rows=1), data_list)
#    2548         return conn.rowcount
#    2549
#
# IntegrityError: UNIQUE constraint failed: actions1.fighter1, actions1.fighter2
